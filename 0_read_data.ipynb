# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import zPLotting
# Read CSV file
data = pd.read_csv('data/data2.csv', header=None, names=['X', 'Y', 'Z'], index_col=False)
# 



# Example usage
file_path = 'data/data2.csv'
start_index = 0
end_index = -1
zPLotting.plot_sensor_data(file_path, start_index, end_index, window_size=1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import zPLotting
# Read CSV file
data = pd.read_csv('data/data.csv', header = None, names=['X', 'Y', 'Z'], index_col=False)

# Example usage
file_path = 'data/data.csv'
start_index = 0
end_index = -1
zPLotting.plot_sensor_data(file_path, start_index, end_index, window_size=1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 12
#      10 start_index = 0
#      11 end_index = -1
# ---> 12 zPLotting.plot_sensor_data(file_path, start_index, end_index, window_size=1)
#
# File c:\Users\Forwa\Documents\Code\Group_Project\zPLotting.py:30, in plot_sensor_data(file_path, start_index, end_index, window_size, sample_rate_ms)
#      19 """
#      20 Plots sensor data from a CSV file within a specified range.
#      21
#    (...)     27     sample_rate_ms (int): The sample rate in milliseconds.
#      28 """
#      29 # Read CSV file
# ---> 30 data = pd.read_csv(file_path, header=None, names=['X', 'Y', 'Z'], index_col=False)
#      32 # Replace 0 values with the mean of the respective column
#      33 data.replace(0, np.nan, inplace=True)
#
# ...
